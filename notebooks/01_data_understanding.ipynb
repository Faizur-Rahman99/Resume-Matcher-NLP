# %%
import pandas as pd
import numpy as np

# %%
df = pd.read_csv("../data/raw/resumes/training_data.csv")

# %%
df.head()
# Out:
#   Resume ID                                        Resume Text  \
# 0   R000000  Education: Bachelor's in Computer Science Expe...
# 1   R000001  Education: Master's in Microbiology Experience...
# 2   R000002  Education: Apprenticeship Experience: 2 years ...
# 3   R000003  Education: Bachelor's in Computer Science Expe...
# 4   R000004  Education: Bachelor's in Design Experience: 3 ...
#
#                         Education  Experience Years  \
# 0  Bachelor's in Computer Science                 2
# 1        Master's in Microbiology                 3
# 2                  Apprenticeship                 2
# 3  Bachelor's in Computer Science                 0
# 4            Bachelor's in Design                 3
#
#                                               Skills                Job Role  \
# 0  Market Research|Maven|Java|REST API|Spring Boo...  Java Backend Developer
# 1  Agile|Data Analysis|Precision|Problem Solving|...          Microbiologist
# ...

# %%
df.shape
# Out:
# (10000, 7)

# %%
df.columns
# Out:
# Index(['Resume ID', 'Resume Text', 'Education', 'Experience Years', 'Skills',
#        'Job Role', 'Category'],
#       dtype='str')

# %%
df.info()
# Out:
# <class 'pandas.DataFrame'>
# RangeIndex: 10000 entries, 0 to 9999
# Data columns (total 7 columns):
#  #   Column            Non-Null Count  Dtype
# ---  ------            --------------  -----
#  0   Resume ID         10000 non-null  str
#  1   Resume Text       10000 non-null  str
#  2   Education         10000 non-null  str
#  3   Experience Years  10000 non-null  int64
#  4   Skills            10000 non-null  str
#  5   Job Role          10000 non-null  str
#  6   Category          10000 non-null  str
# dtypes: int64(1), str(6)
# memory usage: 3.8 MB

# %%
df.describe(include="all")
# Out:
#        Resume ID                                        Resume Text  \
# count      10000                                              10000
# unique     10000                                              10000
# top      R000000  Education: Bachelor's in Computer Science Expe...
# freq           1                                                  1
# mean         NaN                                                NaN
# std          NaN                                                NaN
# min          NaN                                                NaN
# 25%          NaN                                                NaN
# 50%          NaN                                                NaN
# 75%          NaN                                                NaN
# max          NaN                                                NaN
#
#                              Education  Experience Years  \
# count                            10000      10000.000000
# ...

# %%
df.isnull().sum()
# Out:
# Resume ID           0
# Resume Text         0
# Education           0
# Experience Years    0
# Skills              0
# Job Role            0
# Category            0
# dtype: int64

# %%
df["Job Role"].nunique()
# Out:
# 324

# %%
df["Job Role"].value_counts().head(20)
# Out:
# Job Role
# Java Backend Developer      50
# Automotive Engineer         47
# Electronics Engineer        44
# School Principal            44
# Announcer                   43
# Hairstylist                 43
# Cashier                     42
# Audit Manager               42
# Executive Assistant         41
# HVAC Technician             41
# Medical Technologist        41
# Grant Writer                41
# Microbiologist              40
# Conservation Officer        40
# Museum Curator              40
# HR Manager                  40
# Mobile Developer Android    40
# Sports Manager              40
# Aerospace Engineer          40
# Network Engineer            39
# Name: count, dtype: int64

# %%
df["Category"].value_counts()
# Out:
# Category
# Technology                      2511
# Data & Analytics                 568
# Healthcare                       488
# Marketing & Sales                463
# Engineering & Manufacturing      435
# Creative & Design                334
# Skilled Trades                   279
# Operations & Supply Chain        266
# Human Resources                  263
# Finance & Accounting             252
# Legal Services                   245
# Retail & Hospitality             225
# Entertainment & Media            194
# Hospitality & Food Service       184
# Education & Training             183
# Beauty & Wellness                170
# Private Sector Management        161
# Law Enforcement                  161
# Construction & Real Estate       159
# Transportation                   153
# Agriculture & Food               147
# Science & Research               140
# Sports & Recreation              137
# Consulting                       134
# Administration                   132
# ...

# %%
df["Resume Text Length"] = df["Resume Text"].str.len()

df["Resume Text Length"].describe()
# Out:
# count    10000.000000
# mean       168.549100
# std         17.031113
# min        105.000000
# 25%        156.000000
# 50%        168.000000
# 75%        180.000000
# max        225.000000
# Name: Resume Text Length, dtype: float64

# %%
df["Skill Count"] = df["Skills"].apply(
    lambda x: len(str(x).split("|"))
)

df["Skill Count"].describe()
# Out:
# count    10000.000000
# mean         9.495300
# std          1.108829
# min          8.000000
# 25%          9.000000
# 50%          9.000000
# 75%         10.000000
# max         11.000000
# Name: Skill Count, dtype: float64

# %%
print(df["Resume Text"][0])
print(df["Resume Text"][10])
print(df["Resume Text"][100])
# Out:
# Education: Bachelor's in Computer Science Experience: 2 years Skills: Market Research, Maven, Java, REST API, Spring Boot, Microservices, Statistics, SQL
# Education: Master's in Computer Science Experience: 6 years Skills: Statistics, Research, Deep Learning, Shell Scripting, Python, TensorFlow, PyTorch, Network Security
# Education: Bachelor's in Cybersecurity Experience: 3 years Skills: Vulnerability Testing, Problem Solving, Security Tools, Reporting, Risk Assessment, Security Testing, Redis, Django

# %%
import os

print(os.getcwd())
# Out:
# C:\Users\Faizur Rahman\PycharmProjects\Resume-Matcher-NLP\notebooks

# %%
from pathlib import Path

Path.cwd()
# Out:
# WindowsPath('C:/Users/Faizur Rahman/PycharmProjects/Resume-Matcher-NLP/notebooks')

# %%
import pandas as pd

df = pd.read_csv(
    r"C:\Users\Faizur Rahman\PycharmProjects\Resume-Matcher-NLP\data\raw\skills\skills_list.csv"
)

print(len(df))
print(df["Skill Name"].duplicated().sum())
# Out:
# 120
# 5
